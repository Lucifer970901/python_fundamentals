# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
5/6
# Out:
# 0.8333333333333334

# %%
5//6 #this puts a ceiling
# Out:
# 0

# %%
round(4/5,2)
# Out:
# 0.8

# %%
10**2
# Out:
# 100

# %%
10 * 'string'
# Out:
# 'stringstringstringstringstringstringstringstringstringstring'

# %% [markdown]
# check data type

# %%
type(1)
# Out:
# int

# %%
type("a")
# Out:
# str

# %%
type(10.011)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Strings

# %%
strings = "Megha"
type(strings)
# Out:
# str

# %% [markdown]
# Variable assignment

# %%
#syntax
#var_name = values

a = 10
type(a)
# Out:
# int

# %%
a = 'megha'
b = 10
type(a),type(b)
# Out:
# (str, int)

# %%
a = 10
b =20
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print((a*b)+(a/b)) #BODMAS rule
# Out:
# 200
# 0.5
# 0
# 10
# 200.5

# %% [markdown]
# various ways of printing

# %%
print("hello")
# Out:
# hello

# %%
first_name = "laurel"
last_name = "kent"
print(f"the first name is {first_name} and last name is {last_name}")
# Out:
# the first name is laurel and last name is kent

# %%
print("my first name is {} and last name is {}".format(first_name,last_name))
# Out:
# my first name is laurel and last name is kent

# %%
len('laurel kent') #counts the characters and returns the length
# Out:
# 11

# %%
type([[1,'string']])
# Out:
# list
